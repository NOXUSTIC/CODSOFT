# %% [markdown]
# # Character-level RNN for Handwritten-like Text Generation
#
# This notebook implements a character-level recurrent neural network (RNN) to generate handwritten-like text. The model is trained on the HKR dataset (Handwritten Kazakh and Russian) text data.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import random
import sys

# %% [markdown]
# ## 2. Load and Preprocess Dataset
#
# Load text data from the HKR dataset images using OCR. Requires pytesseract and Tesseract OCR installed.
# Ensure Tesseract executable is installed and pytesseract is available.
# Install pytesseract with `pip install pytesseract`.
#
# Import necessary libraries and extract text from images in the dataset directory.

# %%
dataset_path = "CODSOFT_05/HKR_Dataset-master/hkr_text.txt"

# New dataset images directory path
dataset_images_dir = r"C:\Users\User\Desktop\CODSOFT\CODSOFT_05\HKR_Dataset-master\images"

import pytesseract
from PIL import Image
import glob

text = ""
image_files = glob.glob(dataset_images_dir + "\*.jpg")
for img_file in image_files:
    img = Image.open(img_file)
    extracted_text = pytesseract.image_to_string(img, lang='eng')  # Adjust lang as needed
    text += extracted_text + "\n"

if len(text) < 40:
    raise ValueError(f"Extracted text is too short for training. Length: {len(text)} characters.")

print(f"Extracted corpus length: {len(text)} characters")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\*'
# <>:11: SyntaxWarning: invalid escape sequence '\*'
# C:\Users\User\AppData\Local\Temp\ipykernel_23956\3950952651.py:11: SyntaxWarning: invalid escape sequence '\*'
#   image_files = glob.glob(dataset_images_dir + "\*.jpg")
# Extracted corpus length: 65 characters

# %% [markdown]
# ## 3. Create Character Vocabulary and Encode Text

# %%
chars = sorted(list(set(text)))
char_to_idx = {c: i for i, c in enumerate(chars)}
idx_to_char = {i: c for i, c in enumerate(chars)}

vocab_size = len(chars)
print(f"Total unique characters: {vocab_size}")
# Out:
# Total unique characters: 27

# %% [markdown]
# ## 4. Prepare Training Sequences

# %%
seq_length = 40
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - seq_length, step):
    sentences.append(text[i: i + seq_length])
    next_chars.append(text[i + seq_length])

print(f"Number of sequences: {len(sentences)}")
# Out:
# Number of sequences: 9

# %% [markdown]
# ## 5. Vectorize Input and Output

# %%
X = np.zeros((len(sentences), seq_length, vocab_size), dtype=np.bool_)
y = np.zeros((len(sentences), vocab_size), dtype=np.bool_)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_to_idx[char]] = 1
    y[i, char_to_idx[next_chars[i]]] = 1

# %% [markdown]
# ## 6. Build the Model

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(seq_length, vocab_size)))
model.add(Dense(vocab_size, activation='softmax'))

optimizer = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

model.summary()
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        79,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 27)             │         3,483 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 83,355 (325.61 KB)
#  Trainable params: 83,355 (325.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 7. Define Sampling Function for Text Generation

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds + 1e-8) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## 8. Train the Model and Generate Text After Each Epoch

# %%
import sys
def on_epoch_end(epoch, logs):
    print(f"\n----- Generating text after Epoch: {epoch + 1}")
    if len(text) <= seq_length:
        print("Text length is too short for generation. Skipping generation.")
        return
    start_index = random.randint(0, len(text) - seq_length - 1)
    generated = ''
    sentence = text[start_index: start_index + seq_length]
    generated += sentence
    print(f"----- Seed: \"{sentence}\"")
    sys.stdout.write(generated)
    sys.stdout.flush()

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        sys.stdout.write(f"\n----- temperature: {temperature}\n")
        sys.stdout.flush()
        generated = ''
        sentence = text[start_index: start_index + seq_length]
        for i in range(400):
            x_pred = np.zeros((1, seq_length, vocab_size))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_to_idx[char]] = 1

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = idx_to_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

        print(generated)
        sys.stdout.flush()

from tensorflow.keras.callbacks import LambdaCallback
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(X, y, batch_size=128, epochs=20, callbacks=[print_callback])
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.2872
# ----- Generating text after Epoch: 1
# ----- Seed: "eptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? "
# eptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes?
# ----- temperature: 0.2
# kmBbJyaeeobO?As’gmyJOalzmbsspz’k? naN?esryhyOpoga
# mtynength Ozge?wetb?lbBz ph
# hp
# zaammNomekAJrOO?w
# Owg zRnwJ tpOnzbmallRyysRBr
# m?oaBlkJ’nn yheB’?
# B’ezRrrrsJynNBnBkwzn??’lJzpA
#
# sphmso
# bo?A pp’
# hnap’smgstnprB
# hbyBhzNhlayno?gR bpn zgynJgO sa?mmpJb pNkJ?bBRJpzmyRawNRJ’rzNylARgwAtgRt
# bl’z’lkpRwlyAw Opyll’gzktsBNtw bs?J’sgpaAJnehneeswkB
# nnkyypt’on
# ?l?ltr l
# On?l’y
# sJr’ ANAOtA?apBJnwk
# s?nlAlmzw?khwzAN?
#
# ----- temperature: 0.5
# nswbkpBpazt?ByrblJkr
# N
# r
# thrz
#  Ra
# mOb’NbglNgBO’aBh
# sONa
# s?mRNzR rrNbJpk?aOomsmhwO’pm
# OArrnoh nzRm  b?yJ
# meBpa’lwlnaoaob
# ’ohBR
# w?RJg
# pwlpsnmtgzsz?bgOyo?nwJJwpknpoJgkAhOtongyspsezazaoNNwhszlRynrnolew gAzzbhB’
# mkNsmr
# sya’yAy’yJOJl’swht ARkm?ArzntteaNtsnA ’BNpbyb’tBpospN
# beoblpns?zBOlroRRzmNtN’g
# ’n’ylAyNkN?ktJ?gBowt ObAgso
# l gO?mrnkrrkh
# ? mbyzl?JBmolNrmJrAesapJsbk?rNktnoa
# ssyO?BbJAep Oopbb’RAyJ?wR’ml
#
# ----- temperature: 1.0
# mnAlO JnJtONR?bb?NBB’bRyBl? zoyR’NRoRNNaw?’BhRpepawrnAkBsz nbwtkRhzbloBksansN b rooJObpaR’hnOt oByBoplpga JOrsstlmzng?ys l?amRhl
# y?ltON
# JbpaArymROJB’
# r?rk zlgJhorNnezlR o??oapJJs
# ybRA
# zbBbgrw’lbRbt?wnAAstBoO
# hkth’s
# wmwoOOmBgarlykyzglkyBsee
# hAAo’ w’hezAJrAN
# sNosp
# wOwzA rBkzA
# lh kbNoAhJ Nb’k pA’kgA
# z’BRAsBn’’yyJltpR’A
# ABzs?Rnoko’
# OOa ’’plmzBkz
# aROJJ
#  mmrNNe
# tB lpnJeNsogabAh RetNoJyJBNbtyAae
# k’RgnAg’
#
# ----- temperature: 1.2
# atwgkNt knRAmoaal’btpbBrJpOz’OlNzhzpArJnenpyoy?tzgJs?k?r r’zwRhpenoNyboo’yBzzonJR
# Bbpynk ARNmzz e? RAkeN?OeRNnrnke?shngy mAAlhRO r
# AOApnAognNObgl twsh
# AJpRpmwp??mky?oyOhatNkwO’JOkp? stlnpN’eaRmwp An?n’n?AJsphz’r’w
#  ?tmaRlkpggt?NbrR?AylJggRtesgNwObArJehzyb Rywh?nhtNb
# mB’
# sOap’mAhggbrnlRgwRwagnO
# oJ
# R
# m
# ?syny
# gR k’ozNwy JOBJ?apr?lJaeohlpwJbkphkRmOysokezhmtRmrbyotmNnBmBt
# h
# ltybeohet’N?J rbezzOznJ’wgy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 89s 89s/step - loss: 3.2872
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.2567
# ----- Generating text after Epoch: 2
# ----- Seed: "ptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? B"
# ptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? B
# ----- temperature: 0.2
# ry’mrRyb? obOzyznznrnbJsNgoalalblws zJptko Oz
# gmkp?OJaJy hkA?RlOz ekwsykRhnzsn ONp’mwamwlhNsm NzJogOnhh’saekBNywnggozNa?’AtR’’z kRgbhonaw
# rJOB’Jw BR’zybnwtmNmz ’bw
# bA?BOANmwmwmps’?pelA JeRRgOspsypeJlt?az?twJOzpeBwA
#
# s?mwm rNkh?’bbgBOJy?y kAkytewlenztnwonmbJlR’k?gkonno
# emswwoynwRlOb’JAOR?m’rNRlsRy Ne
# monzlAN’’ ?t?rbhpnr?nO rk
# A t?ezyJpen
# ’s
# yRNRnOzanp’spynw’Rsl?mgpgronbg z?N’kAo
# krhA
#  baBe?s
#  alhe
#
#
# ----- temperature: 0.5
# b’Azng
# RanByRmyzsOnw’ephm?m
# bOo’Onzrn?etgelB ’ag?wbOnyaleNaNNRbg?BNoOle’zaylOAtoJtbNNoaAl?Nrt?twrNBw sbNgz?b
# O?AJnNbObnthnRJ
# k
# yOb ONgs
# gkrA?mmJeo y?tttzkagrtgAnJaabOpwrgRy blRpJg bRswt’a’gpm?ONBkohowJwablz?
# mypzBAAynrpAbllAeezNJm
# wyNh op
# mpesoglOmawarkNttsw
# Ro Jmyz ’prrJpzJmBByh lRtaA Nngya a’ozywBbkNlBgbawBmesp
# gOwa gAn?zknORh
# h ph?egnOo
# mn
# aNsbBJolON
# BOJa?oannawbnwmrJBkmO
#
# wy krBmn?wbJnsnek
# n
#
# ----- temperature: 1.0
# OeyJmw
# tyBJt
# ’yJpkbJsAg?sgRnahB’eohyABbJehyeypkwhk’a?BpAhmtwNBwmkkmmo ROo
# pkh? ?lBhNRsrNkBmOenmaet?ekneBk
# OtN
# ’k b rnomgzNksJ’Jawzrs’’yNybJsar’’Aoza?aBRnsg ?Ar
# rokonpwgBhlbwswrkReOmOAhpzNktOn p nAah?nsJnO’Ot?t zeN’Azna m
# baNe’pBz
# tge
# tOabNl’’p ?e Rll
# zRwhzoRhhbs’nN?kBJhAOsp ’krnshlAh?l aoywsOmNmz?JNpmhOazlttmBNrRbkhaJ
# O RAeorB mNRlRbrrn?y sremes
# BJJaoobhRk?p Jp’mOo tOa’asOtkegthn’ hBRng’e’NzByays
#
# ----- temperature: 1.2
# eJy?nJ’beekJo?wJbAwnllmeNJBwsAaohOetmewtpNBmmzzOapg’twkOkmbkrgOoAwlasslh BOwoobmky?yza ama’ttRwtBkseheBtzkekogtznRJNOoopwy’ wmm
# zrla b lORBOg’’AelmsaoAzk
# Om
# r?g
# ?orNspONaNeJyltse
# owJntpzRmy
# obBepsm?R mksnOOplbekl?hhN?soNnpwJ ’ttrnzh ymb ?lebpmJpROwlhR
# h?ozeyNa’
# b’mh AmONsmhpJO
# aeNaO
# nyORNsNaANR?w
# J’relksgbNn?’ARzmkhpwkmb
# tRrhagezsA
# nbtnJhBz BBotA’h?pN’empr?Bsaoy?lakzslRAN
# aRrA? eyBeOetJJAw?A
# h?gBp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 86s 86s/step - loss: 3.2567
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.2260
# ----- Generating text after Epoch: 3
# ----- Seed: "ehe BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem? "
# ehe BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem?
# ----- temperature: 0.2
# mtobkng?gpwtpNasmllnsotao?rNRoAO Bw Om?
# r rkohRz??y?’mhbn
# lOnnkwprot
# pz ’Atw’wlsoO eRA?AmAzs’seyhlnkOo AkwnmO okobJnhe’zngJOyhAyzNO
# bn’RmyARRb’e
# rrezeNzsnrO
# Jet
# mogJebpNNoRB’JkmRN py r
# okyh
# oByybzzz
# B?hnn?’raAsOAb?Nw?eJlNzpArg’mpmz?Jg’Rmrn OmA’lROR
#
# ’waRtnao? ?’
# eo’
#
# mNlR?zzb’?N?eogeNRAoaAyokA?neombnthr?hm okzo’JOBOmBnbko
# o?
# ybkAJppr BAwyta’ky’az?gJmz z?hNpwzmmpmyym?eBz?bz?gleho’
# mbas’aBB’k
# oakgA
#
# ----- temperature: 0.5
# l
# RbrnoJr Bl?oh
# yBBJz?BOgNBk
# m’batn’tAhegbrNbpeJAnbAlRaRenysrms esBayl
# bas N’nBOOrRlAAg?nlwgAOnl’J
# BJbJweetlphNpnw
# lAJhe’ztme?rnwyOba
# kplwpJzzw?oNe?BOgsneJAA’hOtopypeNpsB’pJNlJNJRhOekpoghr?m msr ktygnswANrOzl a’nyNoOryp’eNJAtOrrhOhOJlJJgs’kAaAoOOBamBegmommrspRoAA wsyNO’kazo?zot’lNnRwbBkltgny
# ?y’NwRstlagphmgoarnhmmOzRktAehARkpkes’t
# Rsl?OboeNwJwAmthgsNk NbrRm hhOkopwNpzNzrgNrzkgp AR’bBahems?rhr’RBmp
#
# ----- temperature: 1.0
# ptotwggt?tkBr
# t mw’Nb?tyJlAoko
# phhpgnsa e tw
#
# r rme?ty’ewgmatre
# NkOpawzo
# moobl’AznplRlhtaRRr?RnaJ?rlhps p?abe?rnglOnb pOny?ppO
#
#
# lbwoe?Okwz?haOkR?zmsoR’J RJAAyBtAezNoyn
# Am?o knBa?wmoBpehzBshoNsJnByykmpRllplbl
# gyogw?BR?mahwlRebnJbAhAngnnr
# ’bznNpaRhswBtgeyeBypkhhll
# rsBnrbepzkyAtbr’sNORR by?hh zRgpBwRBybkN?k nNnrgytRelmhbBz?OamNns eAe?rnmpgpphmg’bAko ygo’
# hm’geo mangrnA
# nJ
# epebyOkt
# AlRRahbarys?JRksks
#
# ----- temperature: 1.2
# lO ’’OeJ
#
# lRo ?epe?ABza so
# stzgz?’pek JN?ezNk’pBlmma
# rB’leaOAnrR’?atzgpOs alar
# JylrhblwokstzeOgl rl bhekn b’lemnAmAAzgkAzz
# Rk
# gwor?
# wOBOOOstbRJprAAOwskzoOmeerkJbgaBzrwthRJB
# nhmOa?aBOOrrRto
# az wJ?
# BnNysysNBsBgtNmka?NemrNJkepyk Amem ’rNyewblAg
# mbzlnnOasRm
# y?RO AO?slnhmpzoNnkgrktzbryssRl’?oRwtnAeeOsmeA’htosrke
# ’lmoBNleNmRBhRgbgpBRot Nypbbwrmzlmg aOb?Jer kkOw?pO
# rzJBpbl’’BlNekl ’OassAlpyy
# pA
# nBJ kNJkn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 84s 84s/step - loss: 3.2260
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.1942
# ----- Generating text after Epoch: 4
# ----- Seed: "ehe BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem? "
# ehe BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem?
# ----- temperature: 0.2
# Rkm’ARwo?blmnAt?bNRkwsAeeo’poRkzN’kN
# twb’yet?o
# gz?’ooylk
# gpphkynnmmJ’JmtNbo Nkropno’tkgon?k’w
# ’zRmwysnBbJ?hmJNryJemOny?’?
# ongpk
# Amm
# lkRybAnrmA ybRbgmRkyRpowBeggNennNyyghy’hoRA’whzoa’emAeohlnJkzolrARbh
# byg ?RNmRlbkzyrOmB?r Jm’ tmJwmzt
# nyezo?al’ps’
# e
# Awpla ozmgOrRNROpoo
# r?ebkNAA?mhAyNNmoRJspmNNNmwNbnBgrmmrm
# ynllrmmaN?Jblwgkaoa?AslpenAb?y s?O ?’?
# Bonszk?o? k’
# Jh?ah anBwNor?e?ysynsznb lzek
# oNggrpB
# a
#
# ----- temperature: 0.5
# mpbpNNgs?opb’O aspzk Nbt kko?ye
# lgeowzA onbOb?swAR’Oz o
# k’oJ?eO
# kemAN e t
# znt’arBhAmbRnnpegAppnah
# ?sN AsoOAgyrpwAglBakbtNOsye?zso’ehny’yJBBaslbngRONAOnNNmzygsn Angszb’ eo’’ANtoBwp’oz?mpAO orosomRJwtRakByJy?bpwmwNNe’yknJN JN Ntwa
# NgpNssy
# nbnnz’hh?khNOtmBstsk
# J’ llyrkb’JhbyAhRyOrBwAl zNwwoyROnNJJoR
# oR’pJskhwgkhhOn h?
#  eB’rgOyrOwbwbrJtrhJnemtRzp
# eA’
# gskoOJopgOOro?rwhN
# nol ’ ’?nhz NOBRheOzat
# yhnlw ’’
#
#
# ----- temperature: 1.0
# me
# Ar?J gR
# a?AJesntkNtOrJatAJkyh’Ny loyRaw to’tRN
# gJk ’nOnaAJhwzwAogssy Nh
# sarzoeezt?wRpmkNRaBJpRR
# nk b ’Bt zrmsltNlz?kaRRo’ ’’R
# AbsNmb?hkhaJONnlJanNrppmkgehJA wJ’NoR
#  ns’AzOARAzma?RmypRJa
# sze s?’z’Jgwz’wJ?spArrBrOgAa a ?tzwJpB’onlAbar?Nlagmo gJpgoslnwsmRAlA?w?AhBNrAN
# OAnpkskha zoRRhrJ
# nJOoNzBNOA OAsJk’ yzpz?an’koNhtltb’
# Rkzs?pO’prBRseR
# mObstaOnrzyhrbhJgtptbky
# ?ntg gw’R’ohz?kRwzAnwnRannrrmN
# b kJln
#
# ----- temperature: 1.2
# n wrp’trmnnyzetkJyp?m
# r yt’nynBzn’NNsANm?bwBsJmzn?kmRmyNronlaOonzJaahpBstmknrbN?nwm?mJlogbtgre
# O pob JzB
# N? kwa?RRbtnhAz AmRBhnmNm’b  wnz’AeOemgNneh
# bNoNwhnBlN?g’beBnakkbO’Nsle
# onbosbmRlNyrmo
# lgBlk ’RnmspmAyg??yez AJBmlboAaohywlOrrb ’zwgesOl
# J’ekgrtyzAyho’psl?Jzoaosa’k m zkglJgyNnRtre?OrbBNbhhmBrR ’w OlksAN’p
# aawzwzOrrhhOs’
# sAOBAkJtwwbgBBhmON’’pgpnlbaep?znh’Ana?p’zykkga ttROrpzN ynsonpBhJpshArlBJ
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 86s 86s/step - loss: 3.1942
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.1596
# ----- Generating text after Epoch: 5
# ----- Seed: "
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borrow
# "
#
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borrow
#
# ----- temperature: 0.2
# Or?mOB hoh?lt?r
# s??owAz’anBz
# JeoA
# h l ?alOoBo?hm
# NgRaAwBkBmklsJORAwAl’rNtm’ppo’ggrowmRprNR
# rb?
# Al g?zk?t
# JpbAB  OONblp’ bNOoyoR
# b’lyhzklRhbam RbRB’rlRA
# kmOJ
#  ’AgyhnhABNzeg?z
# kzr
# ?kneAaohgk lRA’AlbzOlnRh?y?g?mNnO
# thmkyoywrsl ze’ReRJobAh
# tzyp?aRwrso
# sw zszJgym
# rm
# w?
# naAke?wo?rb
# R
#
#  Bkm??mgRe?gAOBpRek’nngkRrb
# ’azARmBymhJa?msweBtr
# gN?p?wmOkgnp?nOBeJBo
# bbzwtJozmeytlkmbbpegykwonJzz?n
# tnAA hk?rb
# zrmN
#
# O
#
# ----- temperature: 0.5
# ky
# k m
# ozzhl
# gwrpspJeAhAA?thal mRBw Jkm’RmNp?b
# ’w
# lrJrNRmogtm’on hwsOn’z
# ?R’ NwkaolJh ynho?’hlNmaAmzn’O
# g?’?l
# OABmbtsNpa eoeRNwON?bm wtNR’gzappmam a?AhamAkreazO?bAJ aer ke
# kknmyl
# eBkJkna AJsekobo’ratakwkpBhNynhp?OAB?gNeBmOBpyRzslOrnrmtotmge?kwmB?slsnwApbtm?’ARszOpy by’gtb
# phmeoRo?’kyrnwkprAleA’ pshJraOJt
# o RNeypkg’gnReteOa?lnJzth hrahgog
# ?keAzkmslJ   osBb?wp’
# krmhO
# BzztyzehA’z bBkAAnotmOR’JNwhpR’b
#
# ----- temperature: 1.0
# Jep hNrew
# ’A
# p
# NByAmBbgR?sskzpNoOo’m??tAzegAwJrAzBztpzRNOzzJslmlrhshNykyalmrAhAN’tJbbNObrapg? ? ezh’ptkOobyszhgaAozyhJrgorRegpt’pOAtNyNJammg
# r
# kbRhwotwA?’ba’’tR hzgygnARollesshBsaRph
# ’o?RnJBzeeb
# ggbyhhnoy? OkhONomppzkRsArpRkJ?Am’NANzApooRygmy’ngl lobholw
# glzewawwnBswtztA’k
# sroRle
# BzwobaeatskB
# ow Jtor?B?J?n?’eplBka?aNBstboh
# etromb’? Oops?lBrJArmB
# zzeg’bhsghgB’gBBpz?wm???wtoAOrwtmB gbJJJJOltrl?nrJN
#
# ----- temperature: 1.2
# a
# eprRwazAkl?aOthzsmJlOsemhAzpbhO’w?wBpzo
# hy’t AOOarosrRylhaNrlJwaNkbazOzA
# RonmhwBzpmORNJknw’wNgobtR’NOaB ONbONhNReANp m?lobkpwtJhm
# npJsmObJ
# asrNmAsARt Nz r rR?Bn
# ew
# ’yRAA?rwmlnbp’eoRllJyppBJoyOkAJ’BtAAOln?bp
# bysgkeknOAN’Bktbr’zegyy’kkaeBl?O’lBwoRh’JrtBOknRmao
# znOn?rbbhb
# ?BolRRBp hsA mkAhzwbRgAylghl
#
# otys hJ B’nAOogznBwAOOaoO
# hbJs?yh RNm
#
# wrNhtsz
# bsbmaawtBgRothel aBtJhesrhloplJpBBhwregkaByywzhraRw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 85s 85s/step - loss: 3.1596
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.1201
# ----- Generating text after Epoch: 6
# ----- Seed: "
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonro"
#
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonro
# ----- temperature: 0.2
# Bm
#
# prwJ?O
# kwk O ?Nrpmzo
# ’onaNs?knwmB
#
# Aw
# aORoBooRwl ?zgksh
# phpbRNgoam’wmrOa
# B
# hnpOytBbabnrJlgmrmeptnbozl gJ?AROskynoo
# ?’ go?b?wmm?mb?n? pt
# Bkrp?
# Abhss’l
# ?pgmtlNn?m?a?Bnmpo’’’k’yoploRwsJm
# e’gABmJaR
# e’ow?Brno
# oNkknnh?
#
#
# kn’a’ob
# ya
# yOk
#  Nem
# nrBo
#
# ?n’m?J
# kNgom’k oJg’o
# ozh
# nb kNsB OokmbyprgeNg’sRJgyraoyhlonAnJRnstmzy?obwzO’’mbaN
# ?R
#
# neRkoo
# rJy
# km?Rmb
# ’m
# zBrpb
# ek?OR??oOe’
# nNlooOgtAs
# JkkosneppJh?mR?zyrp
#
# ----- temperature: 0.5
# e
# ObObBtbkk sp?bok?Jt zgANrBNmRNe BnoO’hBzswlJnbr
# atpJw’rgpJsroertrer?NNtJyAhRsorAmlmAs?JnJ
#
# rptmpz
# m
# ryROJeOtm
# moeO’ gOAO?OgmbymJktbBBk??’tabaaO
# wgmJptkAmsnpAgsk? s J??nO wR yk?no ornhmzBokymlkrteAARhAJkt?oaB?nrkB
# okob’’
# lzReBkwARlpBB??wBo
# ks
# moeB?omlm’pal’yOelRJsosbwp
# rO
# tktRm
# sReO BrrkJ?RobemwAbnB’ey oJpw?? geBapnleRneNhR
# brttek’
# aAnk’t’o’’A
# JmJAlnwN’AhAzksalp hh?nlywnBghBo’
# JRONOor
#  J
# RbtA??
#
#
# ----- temperature: 1.0
# zbR’rNno JsOsgR’JReoRwmlkAbRpns?zly?JbahghB’ prgetyrJlrlkyNsezn rgkaJkptJt?lBgnbtnlsgyobnblaatstlw?k
# Rp kRgsR’’hkrt m?tepo
# gRbbmhhangeepRJrmObbN?nhmN’rwloR
# psmhA
#  tBNzpbhwAnhJhzsbyhkkzAp?JBnBnknbJmJo
# wzg?wJoplep?rwemoBkk?’JknbBbtRloebrbelm
# hwyOslo mon  zyalnapN meeR?Rymmabgsrb
# ptn?wlwktsBebJlyAAagwsN?e’JNen’shhaJp sANOrahzhhzgszBs owptahy? ew’NOoskb?ohRnpAlgo?JmbsOwkhhnwlAhgk?p’
# gJlrAARtmk’l’ezny
#
# ----- temperature: 1.2
# AlAeAaRr?alz’AlOpNgzbAJ?pNkBa’obybAnkseOtogbON
# ?’Bb?RBbsl’tObmBborakbR’b r
# RAo?AyRbryrltahp’hN’bskJgJ’
# aklzonyBgJw’alrbONJRlarOb g?llynBl?AyeJROsg rAbymwO ’AybheRkep
# wmaoAlpzb??JaOsRwylz
# hAhtnAehOwBnA bOeJh
# Ngtahb ?lBsepBA?hpyzJgr?r’an?’lphJ eJ?’oJJ’lr
# Nm sbgw yatOgat?m?JeJAA?tNkkNkppetl Rbzk’mn
# JB’bzJhJpskswNtorg
# Nhzes?gnBhkom’bseBog ahmbbBog NNw??ktm ornbOagayRBwbeAp?ekzstkamnnBermtnRpJObBaBB
# bw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 86s 86s/step - loss: 3.1201
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.0724
# ----- Generating text after Epoch: 7
# ----- Seed: "A
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borrow"
# A
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borrow
# ----- temperature: 0.2
# ’O
# bezRrR’o’ yznyaynsBl?npkmAnbl?
# pza?kzkonNz
#  bhbhn’rb
# ye’e moma’rot??
# pbm O?w??k
# oAn?nbkeOr
# nbw?mpJo?N’kb
# nypaleo?brmAoN?go’rgnOn
# ?’m
# mkOb
# zB
# bmgoln
# N
# zanhb
# ???Nozp?ob
# lhmokb
# teoh
# nA
# O?gA
# ?owr
# ’ynl’?A’A
# hnzkmO?phakbhoO
# ’
# n
# bnp
# khn’n
# bR?
# y?mw t
#
# o mk
# t?lNnmA???nm? krAAJob
#  ?RtA?oRbemyA’g
# yOp’rNnennsgBnpz
# wmNpk?eyNlbe? ?zOAmA
# ’B
# ’zAbpnwrrRsemrpm pJnglymbm
# eRsbgp’AAmwobgRkz
# ylN
# t?JmbBR?nnmBrkmo
# ’
#
# ----- temperature: 0.5
#  tyokelOnty
# ’AzwblomBkzOrmJol?nJOtlo
# JtyypazAlrpt?BaaeJlAz’ybrzNgoJksm
# ?hoyahkAgRm
# gn’
# wAAw
# JB?zRn z?b?bkAe
# bNAJllm w?bOwNbz
# k?rpmpygmbogRy?z? nOORpoOtzae
# ’b ymo hBRoebntmobkrAmyn
# o?naAlAtowhymprsrzntsNw’NhmA?n?lzn sky
# ?BNRBJ kBnoJoothabnNrhyey ho’kb lznhRmOohsBt’rbyBgbpnAbrmzBBJmAlggagmbyayAhAo
# sgtJnO pAJgnhazankBms?ho
# gAezzrla ’Jg JmbA?aonz?oz
# wbgemo’zmasz
# tyygl
# zngwlAB’mbnzowOsgB’ NzlgwzRhpwJbR
#
# ----- temperature: 1.0
# rkhgzJhb
# p
# ke’Nzrs
# R aBNlmBRzsJraANppnyep
# lJgahwr?
#  Ormyt tppleRzmsmezA?garh
# n?NoNBkApezNR?
# OpnN yBkzwhyglJmaBmOrw?el emy
# ltokmwyA?yazN
# bhAeeeOoswnz’?BanszpO
#  pmptb’?JNapp’zJN p oaznkbhw’eJaszsRR  gAmglgzo
# A ehOABmnomnzAspwhmzhzotgAmlnmtnOOkl?pwlbs?rR?nAROwy
# nbtrAzABg’rmm
# J
# egl
# e
# eheBbA
# ROzzrb lptyJ
# bntABtBnnB
# gwAykm?
# wlhkR Blh?Aa ghzo’ooo’BNkoe?bO koNapkOh’gR
# gpgwA’RyJ?grANnbbryy
# ’Arozem
# gRbn
# oo
#
# ----- temperature: 1.2
# et msJRbBNnmhnm’rhyORbttN p
# naAlsOrmtrgnaywRrBpe rOAbsgk’agA ’’’k’NargabRrhm
# gaJem
# RyR?
# bk
# gtAAmmJRnAgls?to
# Nkr’kJ?lgh?ktN’Jh?NsmRr’rRAtnAgOrOROaa’tsh
# ’?wlbegwnekmO?wopam otolmNhplp eopal
# kA OogozztbsOt’snRk’pn?rOkr
# JgmslhOkoNrkagyn?n
# JpOsArwrsbAb
# BBgpn?Blrlets?zkbaR’?ARseokege Agay AJoRo?szmnBslzzApzzw’wnO’akgr?B?zoNsnmbayB
# eBANwOylyOrzoObApO? rm’antzkA? ?okmO tAgp’ohAtzsAnpBlephy? ?Re’eznbh?w’Ao
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 83s 83s/step - loss: 3.0724
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.0102
# ----- Generating text after Epoch: 8
# ----- Seed: "JON egpehe BeptagzA
#
# yom’ Reser? Bonrob’"
# JON egpehe BeptagzA
#
# yom’ Reser? Bonrob’
# ----- temperature: 0.2
# o?
# oopkoJ k
# RRoznyomB’
# aoeAmm sRkooA’ ?kz?
#
#
# n
# BoO
# yooo
#
# ek’o
# ?o
# pm’o
# Na
# ?o
#
# JnNtb
#
# ’
# R?Jmn?’ ?pB?zmn?Rb
# Bm
# kz pomo bmohb
# OmBloloe?
#  n
# tr??brrm?opo
# nmBoamp
# rrzmkN
#
# k?bo?lnk?
# y
# r?k??p’
# nkro
#
# ogmk
# oO
# ob
# N’oa
#  ?b
# hp’b
#
# loob
# o
#
# zon gr’s
# mooB
# yoA?
# gom
# ?z
#
# s?nmNypho
# kBkrbblN??m
# bnwmktoO
#
# k
# t
# ?B’tgmonskroBNmym
# ’?ak
# b?zm?kobNkoOkJok ’Bkg
# bgnn?zJzRnanybbk?by bntNw?N
# ?kBg’wsonhB’pN
# ’
# ’?’
# brbnNgzmwNoBno’oz
#
# ----- temperature: 0.5
# wOJprzAkkkRNpb
# ?gnNrn
# toAO’ yhOtlOJpzoJeOmokrO
# ’’ro’Nn
# R
# sk
# N’nybh’kRlegblkklbebo’ye?No?l’mNJAeRRmhkRog
# noobwR h k’
# rrzmAgABhJOrosNzmAgN
# Ogp
# eJolpsggwhgyA?hAr
# eOOzJwyyBr
# herBrrm’bok
#  blJ oAOpnnl bkoo R  skgsgeRzR’z?hyhzlopeyeg’?bNw khknRoBan
# wgOboohRhmanagsnmkwmRzOBwpJmpAhnmNgygzhNp?pArnlbzJw?a
# Jry
# hekBJmkh??eJJ’lBboJBBmo
# obt
#
# bN slb
#  OnlOn
# Onoboass?ewzAAo
# hReazk?whJOR’rkNNgRnyp
# h ko t
# BBkJ
# ?B
#
# ----- temperature: 1.0
# Aserbrbl?BbNanpgbnnnop ARbNslzNoJ kJbwArAaJw?JOlsgtroO
#
# ’hwlmlkArNNJ?J ’sN BhtpmAlhebheB?g?k?aJAhp??aOgJaOztl’gAtslkhoAwRabl aJtgz ORztspbOpbpnrhhJ’’egAyAJB
# mk’RRgeB
# AJsRsrl
# ymkpeozar’’tbpNaee
# o
# olmsRahbytw?yO
# BnhOszb?Nm’ mhw
# lyhmRaAsltwwnwNsnBl tggnopzAoA
# ktgw’lmyrszgereBAAhA
# mO
# apmOr
# hw?snsORlNpwOrzms?mrynkhtJs’so kAkg?e teAb
# e
# et’yw wleOylJ’nhyAOlkysg?zJ
# glbBly’moNA’eAoOgrnoJp’byBOlRerzleRe?
# ?t
#
# ----- temperature: 1.2
# B?bmyhOAys
# bBe
# ’N
# nlBppNpoeg’AzOOh’Jt
# nOkgoholwR?N’nwbJythlm
# yytlhzp BNBab?nss
# lsNtJwA?’RAz eaykn
# arszzeAoeo?wboONgzyBleb
# NaJOrrbNOeabpON
# obngerNsJtnr
# nmln
# sBNNR’ztmoszgha Aab
# b
# ao brBgs?
#
# eym aRAwOtAoRasNga
# yAel
# wegkekoymJo’ysRygtOahs
# rON? nog?z’hhm? JynglOlBmbweBz??prbsROmogpAbpA?NotoAw
# Jwes’
# R ’ Oyezo hJ?B?thwArbBNzg?Jwy
# zm?’rnJO
# nJmOkztz?JJOJmepwgoso’’zr
# lwRNo?wtn
# rnR k?wkkmrJN
# ’l
# gNaJ
# ooRswwa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 85s 85s/step - loss: 3.0102
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9226
# ----- Generating text after Epoch: 9
# ----- Seed: "
#
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonr"
#
#
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonr
# ----- temperature: 0.2
# ooono?
# Bb
#
#
#
# o
#
# mo
#
# ’
# o
# ??
# o
# oOo?o
#
# n
#
#
# o
# N
#
# o
# o?nob
#
# ’
#
# n?r?
#
# ob
# epmm??
# er
# soBABomom
# ?
# b?
# o
#
# n?
# bR
# g
# Rr
#
# m
# otot?
# ?roo
#
# k
# koeR
# eA
# R
#
# eo
# oo
# ?An
# ykeRo?
# oO?
#
# o?ko
# ?mook
# o
#
#
#
#
# nomkk
# A
#
# oAm
#
# naRnoon
# ko oeNbm??m
# nnr
#
#
#
#
# o
# oo
# ?
# ?oo?t
#
#
#
# b
#
#
# b
# nbo??eo
#
#
#
#
# ?
#
#
#
# non
#
# h
# m
# bn
#
#
# o
# n?og?bko
#
# O
#
# o?n
#
# O
# p’m
# monb
# ?
#
# n
#
# g
# nomonB
# k
# m
# rzeo?
# zb
#
# y?bpm
# o
#
# ono???b
#
# nnBA
#
# n
#
# R?
# o
# o
#
#
# tkooz??a
# n
# ?nbo
# okok??
# ?
# ?
# Amonb? o
#
# ----- temperature: 0.5
# ’z ?yob
#
# bro
# n’pkzkmmob’o ’ O?z
# rooR’’OOnrsrA
# l
# Ogl
# mR
# Nz
# ooBmaROk
# Jr
# mor
# lobombnoB?zg’
#
# w
# ?RzmerBaokzbNsp
# ym’m nkaolBbrom
#
#
# e
# z
# oR Aeb??wRyn’ozRme Ne
# ’kn?’Oob’
#  ABwOORnn
# noh’s’?Ogop
#
# mBreobOb??kbOo
# e w
#
# romAhoBrzbz?nAmtnAs?e
# Ob?e
# eolo?BhmnN
# gtn
# bwbzet’RgBzaB?’kN
#
# kA
# R?b
# BBnrk
# m
#  ?
# ormo?pe
# R?Ab
# RNlo?R
# hApzBm?b
# Ar?ob?
# ’ mr k?r?roaonr?ogokkzom?n?’mm
# oNb
# kkRJJok?
# ?p
# bh?rne?m’mb?w??O
# A
# OkbA?toz
# ’
# Rz
#
#
# ----- temperature: 1.0
#
#  J’k?z
# oA
# gbAlAOr
# Rz’wk’kAoANtybb
# ylaoOAawwk’pR’smnepAz’eRmpsspste
# omNRltse?lNhslb
#
# ’BreeRbobrsgNmpop?grArlAthlrm?kwnN
# ehp
# hb?e
#  ’kkbkRookbopB?zy’Ryaol’elzN bg?b’Nmo
# htbpazozBtpB?oOAzABoOmewRokgN
# oByNk’kbwOgN?nms ybonyowymNy?lh’bOwk
# BlerAAloNpaJskgJJNrs?k’?myAymmm?aptAzprR
# AkA?JRlBJzyNo lJrANOhBbp’ebs?s toNn?y?onanr’h
# tyohntezloBkkkylRbO?’rk? ablzkrns?ew?hre
# ehn’skm rAyekr  oAomtah
# nmoBaBBbnOrn
#
# ----- temperature: 1.2
# p aJomokpsO’zl hwz
# e
# rway?trmOgy’oez?pmaaaRRs’nzybaehbwrylypArn O?eNzn
# asoA
# ?Awn?e?
# Nmowamb?aB?no
# hkpBBawblnBaynkmhbr
# oN
# nAa
# lrbN olheApeBBnwRommN
#
# ne
# JbooOonzwnmJmOllpmyOoz
# aabBt
# gkJA
# nAw Rg
# ?shOahJ ?aJyblNbgk’e
# Ja’
# nBAmommoJ
# ’h AhBleNtna?ep’booJete   o bpylB?sam
# y?psRr’ztzlbyh
# z?rpoAlzN’rA sNlAm ytmnrpONyzon ypwyRRskm ’yoApnyalk
# pb
# pe’OtzrbmoNhpJtO’?mekAbsooJJgkoN?ergkso?BgJgy?
# pJmkarbrraynozpo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 87s 87s/step - loss: 2.9226
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.7889
# ----- Generating text after Epoch: 10
# ----- Seed: "gpehe BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem"
# gpehe BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem
# ----- temperature: 0.2
#
#
#
#
#
# ook
# o
# b?
# ???
#
#
#
# o
# Am
#
#
#
#
# b?o
#
# o?
# o
# o
# o
#
#
# o
#
#
#
#
#
#
# o?o?
#
#
#
# ?
# ?k
# ?
# o
# mo
# o
#
#
#
#
#
#
#
#
#
#
# Bo
#
# o
#
# ?em
# ??ooh
# b
# o
# mo
# RR
#
#
# m
# pwk?
#
# o
# o?
#
# ooom
# ?
#
#
# ??
#
# m
#
# n
# oon
#
# ?
#
#
# oo?no
#
#
#
# ?
#
#
#
#
# n
# o
# ob?b
# oo
#
#
#
#
#
#
# m
# o
#
#
#
#
# mm ?
# n
# bmoB
# o
# ?
# m
#
#
#
# n
# ?
#
#
#
#
#
#
#
# mo?
#
#
#
# ?
# o?
# n
#
# ?
#
#
# o
#
#
#
#
# o
#
# ?oo
# o
# om
#
# ??
#
#
#
# ??o?
# ???o
# ?o?
# oo
#
#
# on
#
#
#
#
#
#
#
#
# ?
#
# o
# k
# m?oo
#
# n
#
# m
# ?b
#
# ooNoo
#
#
# ?
# oA
# ooo
#
# mb
#
#
#
#
#
#
#
#
#
# ?
#
# koo?
# m
# ?
#
#
#
#
#
# ?o’
#
#
# oonno??
#
# n
#
# oo
# ?
#
# m
#
#
# ----- temperature: 0.5
# ??
# ro
# esmrA?o’o n
# n
#
# ?g??phoaJ’nkob
# tonwbpBbnmo
# ?
# n
#
# Bm?
# g
# bsmN?o
# ozo
# kbno
# AR
# o
# ’
# m?bNB?rJ
# Oop
# r’ObRkb
# oo?pezmOkgobo?oyJ
#
#
# wot?m??’?g
# mn
# bbb
# nnw
# ?ztyr??lnp?nnboosoonm
#
# mAk
#
# soo
# kk
# my
# m
#
#  hbh?
# ooomo
# ss
# oOl
# mmwyAgAm
# ?B?r
# l
# ke’No
# o
#
# b
# ktnrom?oe
# w mJ?z?ogkmnoBtOgw
# NpOewkB
# ’okoobba?eeO
# ?kenyko
# o
# r mB?
#
#
#
# ’Bno
#
#
# kmbONb’l?Aroo
# ?o
# mtoomkka Jo?
# m
# blBo? e?o?kBkoeonoozm’nohr
# molA
# epkk?BAJ
# o
# sk
# r?
# p
# oOsnk’
#
#
# ----- temperature: 1.0
# mB?gJr?zwNkpzAOh snrN
# m’Onn’Noboarn
# hteNbao’mNywmmasrOezmhtanJB’Bzbb?AgkRkJ’tk’aJmJlNbaeol h
# bkgmJl
# Rn
# gAR eObyNt’Nyakomoo kwA? snzwRnAo rwsgo
# zots’Jtwy’NAOAhnhzzzb?gn’nr’b
# korprROonRRRbNsByO
# akB
# e pmmww
# ga
# nmAmR J’tepntsR
# b
# kNzz’l Jopsz
#  kg?hOo’bRzz
# Rghn’N?
# JRmbegnagbnnkmeJnpmotmoJaoRt RwNo’m gnkk’sh’z?JtNoJeOBzeonO
# k?BoaR’tkrkoA
# malkpBOko?oooOm?k’gNghmw’r’Oz
# rz
# yBkren?oJb?yseBzt?robR
# npBasgraeoy
#
# ----- temperature: 1.2
# mlmtO’?kkNmgzJoz’Rk?OpylannaOe’’OBJls’lnezoopby’zrzOAh?sBO
# khRll
# mo
# k
# ?ka sbOro’l
# b
# nykpR
# ?t??eobm ooBpp
# orblJopkNtpgmszpnbOme
# Brtpwra
# tmN’?rrwzRlrOlnzrptBoloBymmohOw
# ?’
# lpbRzkyk?kogAlnRAan tw?rwhwmmg
# z’bNozhOAAnRel
# ’brgmramlO
# yllbyeokmAae laOgleBBkok p?mzphb
# eA?AhNJBs?ypnnn
# a’obl
# lzBobsJJ
# m?
# ?’sJlolwgA?mmprpyomk’Amzk
# n
# oy? O?A
# snn zmm z
# zny a
# hJyzmNO’el?Bkysa
# gnoNnbnO
# J sr
# hObhbr?snBApJ’nknAlkmRB
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 85s 85s/step - loss: 2.7889
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.5782
# ----- Generating text after Epoch: 11
# ----- Seed: "zA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borro"
# zA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borro
# ----- temperature: 0.2
#
#
#
#
#
#
#
#
# o
# o
#
#
#
#
# n
#
# o
#
#
#
#
#
# ?
# o
# ?oo
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
# ?
#
#
#
#
#
#
# ?
#
#
#
#
# o
#
# oo
#
#
#
#
#
# ?
#
#
#
#
#
# oo
#
#
#
#
#
# o
# o
#
#
#
# oo
#
#
#
#
#
#
#
# ?
#
# o
# o
#
# o?
# o
#
#
# oo
#
#
#
# o
#
#
#
#
#
#
# o
#
# o
# o
#
#
#
#
#
# m
# o
#
#
#
#
# o
#
#
# ?
#
#
#
# n
#
# oo
#
#
#
#
#
#
#
# o
#
# o?
#
#
#
#
# ?
#
#
#
# o
#
# o
#
#
#
#
# o
#
#
#
#
#
# o
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ??
#
# o
#
#
#
#
#
# n
#
#
#
#
#
# n
# n
# o
# o
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
# m?
#
#
#
# o
#
# o
#
#
# n?
#
#
# o
#
#
# o
#
#
#
#
#
#
# oo
#
#
#
#
#
#
# o
#
# oo
#
#
#
#
#
# n
#
#
#
#
#
# oom
#
#
#
#
#
#
#
# o
#
#
# m
#
#
#
#
#
#
# ?
#
# o?
# o
#
#
#
#
#
# o
#
#
#
#
#
# ?
#
#
#
# ?
#
#
#
#
#
# nooo
# o
#
#
#
#
# o
#
#
#
#
#
#
# ----- temperature: 0.5
#
# m
#
# ?om?oon?
# bnb
#
#
#
#
# obno
# bo
#
# n
#
#
#
#
# mm?kO
# oo
#
#
# b
# nnNnkRno
#
# ?n?gobho
# oro?’oboommoA
# o
# o?oooo
# ???o
# nb
# o
#
#
#
#
# ?o
# ?
# ?m?
#
# m
# om
# ’?ooo
# N
#
#
#
# om?
# n
# ’a
# obk
# k
# ??
#
#
# o?m?oo
# ok
#
# zomon
# mo
# s
#
# nbpo
# ?ohm
#
# R
# n
# OnbmBo?o
# n?
# okRoOk
# o
#
#
# Jn
#
# op?BOko?Ny’oo
# r
# ’
#
# n
#
# n?prOo
#
# ooo
#
# ?
# ok
# m?
# n
# n?
#
#
#
# omm?ko
#
# ?ho?
# n
# o??Nm
# ?
#
# b
#
# b
#
# no
#
#
# oJ
# bom
# koo’
#
#
#
#
# kmo?
#
# bo’ynokon
#
# mt
# ?O?Bbko
#
# mo
#
# o
# oo?bn
# b
#
#
# By
# n
# moOoo?
# gohkn
#
# o
# onnnn??
# o
# p
#
#
# ----- temperature: 1.0
# obmmorrk
#  knonooopmrkk
# o
# gh
# mbkb’N
# m?yn
# zOmk
# am
# ky
#
#
# eNobzge
#
# bRag’m?Jkbheloe
# lyRm
# RtJNban
# g’lr
# r
# BmAz n?n
# r’mRb’o’k
# moNksNRzryoNR?r
# h?by’k mstrNznkkmAoR
# r
#
# tbB’yRNwy?nbkeobOe og? tw
#
# nor
#
#
# bzaOt
# gzn
# R?mbhon BmowgelBo?bg?
# koko oek
# gobbmJpz
# obk mkohnOlnNr?
# p
# ao
# ’AmRhb?lbykrN?A ggb?mooke
#
# ?e’yom
# bh’nn’kgRbeo
#
# nobbkkOoobJborkt NkA’obnyzk’bom?ba?nmgbkr?n?p’k
# moookpb
# ?kg
#
# JNt
# brmbw
# N AzJkreonpkANOono
#
# ----- temperature: 1.2
# oR
# nk
# kk’m
# OkNn
# ?n
# nb?om noBrwkgmmonpB
# prk
# hwk
# bbo
#
# lp
# r?gg
#
# OBkznemAho?nbk’
# woo?r
# BeepzONOkkrbAka
#
# nNkmoAesknR??gphe?o?aOl?thkm?Rb
# oesrononpOmoOkbogwblzs
# mAo?
# bannN’A nnow
#
# tmbBR
# zyhJ
# rotr’
# nk Oh?Jsm
# mn?gzpeArwk
# ogmbg
# e’p
#
# nt
# knznNetNkNo
# anNseN otorkOob
# boyp?o’w?bg k nat
# g’ o
# ngpsO’kmp?m?rReO’oJyoer
# zOBomob
# m
# JbhonskoAaebkby?sB
# ’O? zoblop
#
# zo
#
# oh’lk?
# nn?kn
# NmeolkRb?pJamtlaRkrt???B p
#
# y
# BsoykRng
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 90s 90s/step - loss: 2.5782
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52s/step - loss: 2.2955
# ----- Generating text after Epoch: 12
# ----- Seed: "
#
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonr"
#
#
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonr
# ----- temperature: 0.2
#
# o
# oo
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
# n
# o
#
#
#
#
#
#
#
#
#
#
#
# ?
#
#
# ?
#
#
#
#
#
#
#
#
#
#
#
# ?
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
# oo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o?
#
#
# o
#
#
#
#
# o
#
# o
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
# o
# ?
# o
#
#
#
# ?
#
#
#
#
#
#
#
#
# o
# o
#
#
# o
# o
#
#
#
#
#
# o
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
# o
# o
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# n
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
# ----- temperature: 0.5
# ?
# R
#
# ?
#
#
# mo
# ?n
# o
#
#
# k
# ?ob
# b
# oob
# ?
# ?bb
#
# o
#
# m?
# zo?J
#
#
#
# o
#
#
# o
#
# b
#
#
#
#
#
#
#
#
#
# k
# ??g
#
# ?o
# onno
#
# o
# oo
#
#
# m
#
#
# ?
#
#
#
# n
# b
#
#
# ?no
#
#
# on
# o??o
#
# ?o
#
# ?
#
#
#
#
#
#
#
#
# o
#
#
# oonok
#
#
#
#
# o
# ?
# o
#
# o
# o
#
#
# o
# o
# mmo
# ??
#
#
#
# o
# mo
# o
#
# o?o
#
# onb?
#
#
#
# ??bm
#
#
#
#
# o
#
# ?o
#
# b
# n
#
#
# ?
#
#
# o?
# ?
# om
# toon
# oo?
#
#
#
#
#
#
#
#
# o
#
# oo?o
#
# o
# o
# o
#
#
#
#
#
#
# o
# ?oo
#
# n
#
#
#
# onmo
# omo??
#
# oon
#
#
# ?
#
# on
# o
#
#
# n
#
#
#
# o?
#
# n?
# o
#
#
#
#
#
# ook
# ??
# r
# n?o
# oom
# b?
#
# k
#
#
#
# ??
#
# onno
#
# o
# o?
#
#
#
#
# b
#
#
# ?o
#
#
#
# n
#
#
# ’
#
#
#
# k
#
#
#
#
#
# ----- temperature: 1.0
# o
#
# ?oobkmno
# No?s
#
# mbok?zo
# ??ob
# ?’
# ookooo
# mm?o??nRn
# ’?
# k
# ’?oz
#
#
# ’nnb?omnOB
#
# ?mo
#  Brn ?
# ??
#
# knoy’oOooo’
#
# bemorbknn
# ?R’?
#
#
# oo?n?bn
# ?RkooO?R
#
# e’lmb Bm?
# Jm
# r?o
# mz
#
# o
# AB?
#
# b
#
# b
# O
# ’
# saozAok
#
# Jbk?o
# mgmbN
# ob?
# mnnboRnnAn’ekkoonoOo
# kmobml
#
#
# rm
# rnzbOo?o?oo
#
#
# m
# b
# n
# Ao
# w
# z
# m’
# o
# b
# nmo? ot
#
# mA
# bo?pkm
#
# n?m
#
# o?m?ro??
# b
# bo gh
# m
#
# bb
# kso
# b
#
# J
# kp
# oOA?hA
# ’
# opA bomegr?bB’’oknk’
#  o
#
# Jp
# ?
# O
# oo?bbb
# mon?bke
# rbenoNbkb
# ?noo?b
#
#
# ----- temperature: 1.2
#
# momJnbblrnmoo
# o
# nko
#
# ?o?
# b
# ko?nok?mb
# n
#
# m?gsk
# obk?
# r?
# hAbn???mn
# n?BnbeOnRbo
# obsm
# o
# mo
# ?n???myBstJy
# kJAoon
#
#
# o?oBnno
# ?o
# sk’
#
# o
# ?l
# pNr
# ON?mebo?ooaolsloRo?
# ?obo?
# z z?n
# oooann?o
# ?
# ??oronoo
# nbt
# ?ozoog
#
#  pm
#
# ’?o
# l
# za?k?
# ?oozeR
# ombrwo
# s?oOny
#
# ?tAk
# nnm?o
# o pooz
# y?Oww
# bmNoNo?
# b op
# b?
#  thonozo’nnmoooo
# m
# noOroRN
# w p
# zo
#
# n
#
#
# mha
# bA
# bobo
#
# omotmk
# ?
# gpRmo
#
# ’o
# ok?lmNm
# ?
# o
# mokn?ebmmk
# ??ek
# ?oJ
#
# ong
# ??N’?A’mkOoB
#  r
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 193s 193s/step - loss: 2.2955
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.0945
# ----- Generating text after Epoch: 13
# ----- Seed: "agzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Bor"
# agzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Bor
# ----- temperature: 0.2
#
#
#
#
#
#
#
#
#
#
#
# o
#
# oo
#
#
#
# n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
# ?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
# o
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
# o
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
# o
#
#
#
# o
#
#
# o
#
#
#
#
#
#
#
#
#
#
# o
#
#
# o
#
# oo
#
#
#
# o
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
# ?
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
# oo
#
#
# o
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
# o
#
#
#
#
#
#
#
#
# o
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
# ----- temperature: 0.5
# o
#
# o
# oo
#
#
# obon
#
#
# ?
#
#
#
#
# oo
# o?o
#
#
#
#
#
# oo
# n
# o
# oo
# n?
#
# ?
# ok
# o
#
# m
#
# bm
#
#
# ?o
#
#
#
# obo
# o
#
#
#
#
#
# ?
#
#
#
#
#
# o?
#
# o
#
# oo
#
#
#
# ?
#
#
#
# ?
#
#
#
# o?
# ?
#
# obo
# o
#
#
#
# o?
# o
#
#
# n
#
# o
#
# omomoob?
# ooo
#
#
# oo
#
#
#
#
#
#
# y
# o
# ?
#
# o
# k
# o?m
# n
# b
#
#
#
# o
#
#
#
# ??oo
#
#
#
# o
# n
#
#
#
#
# o
# mon
# ?none
#
#
#
#
# oo
#
#
# o
#
#
#
#
# no
# o
#
# o
# m
#
#
# ?
#
#
# ?onk
#
#
#
# ?o
#
# onb?oobo?
# o
# k
#
#
# ?o
# n
#
#
# o
# m
#
#
# o
# omo
# o
# ono
#
# o
#
#
#
# b?
# o
#
#
#
#
# ?
#
#
#
#
#
#
# oo
#
#
#
# ?o
#
#
#
#
# o
#
#
# oko
# o
#
# oo
# o
#
# moooo
#
#
# ?oo
# oon
#
#
#
# ??
#
# o
# o
#
#
#
#
#
#
#
#
# o
# ooo
#
# o
#
#
# ----- temperature: 1.0
# b
# omno
# mmon?ok
# ?nbmNoko
#
# ?n?kk?
#  o’o
# on
# on
#
# r
#
#
# e??oronroo?
#  okB?nbm
#
# ome
# bo
#
# k
# ?
#
#
# NRb?
#
# ?nos
# mkoooo
#
#
# mo
#
# b
# ?b?o
#
#
# Nom
# ?bob?bog?
# om
# ?om
#
#
#
#
#
# o
# y
# ?o
# o?o?
# onob
#
#
# moo
# kkn
# mnnn
#
# oo
# mobomk
#
# ro
#
# Aokn
# ?
# m
# ?oo?Oo
#
# n
# k?
# lonokok
#
#
#
# nnm
# ono
# o??
# ’
#
# kbmo
#
# m??
# oo
#
#
#
# o
#
# ?n
# koAro
#
# ??
# o?’?k
# ?o
#
# ’o oe
# m’no
# ?
# ?m?n
#
#
# N
# m
# o
#
# bo
# k
# moN
# k
# nn
# o
# ’eono
# ?pg
#
# pBn
# omN
# okk
# o?
# o
#
# o
# o
#
#
# ?o?bo
# on
#
# o m???obo
#
# k
# m
#
#
# ’?
# o
# e
# ?no
# ?k
#
# ----- temperature: 1.2
# ?k
# o
# mmn?
# mmk?oo
# oon?mp?
# oo
# o?
#
# nkno
#
#  mn
#
# ON
# ko
# on
# zoAo’e
#
#
# moboooobbo
#
# N
# b
#
#
#
# r
# ?m
#
# ?e
#
# k
#
# no
# monh
# kkbAz
# ?
# opo
# o
#
# r
# obom
# h?
# mno
# n
#
#
# ?oo
#
#
# oo’nm
#
#
# o
# ?kn
# z?olN mtnom
# gemon?lkoo
# ??bO?omA
# oo
# akootn’n
# ?
# n
# bn?rm?N?tgg
# b?
#
# orN?
# wk
# ?nboJ
#
# ?
# k
# e??
#
# morm
#
# mbn??koobrgok
#
# b?eo?
# ?oe
# ?n
# yhoo
# ??nO?o
# ’nm?o
# okoa
#
# ?
# o
# onwbomo
# om
# b
#
#
# bmO?
# hre
# ?
#
# m
#
#
#
#
# opeom
#
# b
# ?hmmoonb
# m
#
# Ookbobkoo’o?o
# b’bek?l
# ??’o
# ow
# me’
# ?
#  ngkNm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 85s 85s/step - loss: 2.0945
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.0367
# ----- Generating text after Epoch: 14
# ----- Seed: "gzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borr"
# gzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Borr
# ----- temperature: 0.2
#
#
#
#
#
#
#
# o?
#
#
# ooo
#
# o
#
#
# o
#
#
#
# o
# o
# oo
#
#
#
#
#
#
#
# o
# o
#
#
#
# o
#
#
# ?
#
#
# oo
#
#
#
# o
#
#
# oo
# o
# ?
# o
#
# o
# o
#
#
#
#
#
# o
#
#
# o
#
# o
# o
#
#
#
#
# o
# o
#
#
#
#
#
# oo
# o
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
# oo
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
# oo
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# oo
#
#
#
#
#
#
#
#
# o
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
# o
#
#
# oo
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
# oo
# o
#
#
#
# o
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
# o
#
#
#
# oo
#
# oo
# o
#
#
#
#
#
#
#
#
#
# o
#
#
#
# mo
#
#
# o
# o
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
# o
#
# oo
#
#
#
#
#
# o
#
# o
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
# oo
#
#
#
# ----- temperature: 0.5
#
#
# n
# omo
# bbo
#
# oo?
#
# no
#
# mooo
# oo
#
#
# on
# k???
# o
#
# o?oo
#
#
#
#
#
# bo
#
# oo?nom?
#
#
#
# oo
#
# k
# mo
# ?n
#
# ooo
# o
#
# oo
# ?
#
#
#
#
#
#
# ?o?
#
#
# o
# o
# ?
# noo
#
#
#
#
# ?
#
#
#
# oo
#
#
# o
# o?b
# n
#
#
#
#
# on
# o?
# o
#
#
#
# o
# oo
# o
# ?n?
# o
#
# oo
# mo
#
# o?mo
#
# n
#
# o
#
#
# o
#
#
# o
#
# ?
#
#
# oo
#
#
#
#
# o
#
# oo
#
#
#
# oo
#
#
# m
#
#
# oo
#
#
#
# k
# o
#
#
#
# oo
#
# om?
#
# o?
#
#
# ooo
# o?
# ?
#
# oooo
# o
#
# mo
# noo
#
#
#
#
# o
# ooo??o
# o
#
#
#
#
#
# o
#
# ?
#
#
#
# oo
# o
# m
#
# nm
# no
# o
# o
#
# m
# koooo
#
#
# b
#
#
# o
# omokmo
# o
#
# oo?o
# oo
# o
#
# ?o
#
# o
# o??oo
#
# ?
#
# om
#
#
#
# oo?o??o?
#
#
#
# o
# ?
#
#
# ?
#
#
# ----- temperature: 1.0
# ?n
# nmo?o
# o?b?bo
# ?b
# o?n
# on?bo
# o?o?
#  o
#
# ?mo
# oo
#
# n
#
#
# bb
#
# bnr
# omm
#
# hn
# k??
# rooe?nb?
#
# ooo?e?mno
#
#
# omonoRo
#
#
# oBooo
# o
#
# ?o?o
#
# o’o
# o
# o
# nomnb?
# kn
#
#  o
# boo?n
# o?
#
#
# no?
#
#
# ?no
# mo
# k
# ob
# o’am
#
# l
# km?o
#
# omg
# ?
#
# obmBe
#
# o
# ?rmmomooom
# n
# n
# ooobnb
#
#
# ?mm
# o
# ooo
# wnyr
#
#
# Nmo
# o
# oo
# ok? o?
# b
#
# mr
#
#
#
# ?o
# b
# o
# o
#
# m
# o oo?nb
# ooBon’
#
# n?oboo
# ?
# k k?mo?mmo??mmbRb
#  ??
# ’mrm
# okb
#
# a
#
#
# n
# omo
# k
# ?oo
# s
# om
# rmk
# ??o
#
#
# o’t?omno
#
# oooknbo
# klrrbmo
# ?mm
# mz
#
#
#
# ----- temperature: 1.2
# ?
# ??m?
#
#
# b?
# ?
# O?bnon
#  bo
# o
# ?b?
# ?
# bm
#
# one???y?
# ono
# n
# k
#
#
#
# bbkbR
# bzob
# m
# bbm
#
#
# rb?ko?
# l
# obm?bm
#  o??m
# o
# kb
# om
#
#
#
#
# bmwNoo?oom
# nA
# o
# O
# oJ
# Rom?n
# Jo
# h
# to?? k
# rpkbo??b
# o
# no
# ?Boo
#
# o?oo
# ?k??k??
# ooom
#
#  oos?oJh
# o
# ?
#
#
#
#
# ?’m
# on
# b?
#
# ob
#
# ?n?m
# ?R
# mn?omoonokooop
#
# ?onmnRAo
#
# m
# pn A’
# om
# m?
# omb
#
#
# nk
# o?nomm
# o?bononO
# nonkmn?o?k?oo
# b bom
# g
# ono?ooeobo’obampnm
# o
# k
# Rm
# b
#
# ?
# ?o
# omkkbm
# mpombnk
# kmo mm
# b
# ?ok
# J
#
# t
# mBn
# t
#
#
# owo??kNo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 85s 85s/step - loss: 2.0367
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.9947
# ----- Generating text after Epoch: 15
# ----- Seed: "
#
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonr"
#
#
#
# JON egpehe BeptagzA
#
# yom’ Reser? Bonr
# ----- temperature: 0.2
# o?oo
#
#
# oo
#
#
#
#
#
#
#
#
# m
#
# o
# o
# o
#
# o
#
#
#
#
#
# oo
#
#
#
#
# o
#
#
#
# ooo
# o
#
# o
#
#
#
#
#
#
#
#
# oo
#
#
#
#
#
#
#
#
# o
# oo
#
#
# ?
#
# ooo
#
#
#
# o
# oo
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
# oo
#
#
# ooo
#
#
#
#
# o
#
#
#
# o
#
# o
#
#
#
# o
#
#
#
# ?oo
#
#
#
#
#
#
# o
#
#
#
#
#
# o
#
#
#
#
#
# ko
#
#
#
#
#
#
#
# o
# oo
# ooo
#
#
#
#
#
#
# oo
#
# o
# oo
#
#
#
#
# ooo
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
# o
#
#
# oo
# o
#
#
#
# o
#
# ?
# oo
#
# o?
# o
# ko
#
# oo
# oooo
#
#
# ooo
# o
# oooo
#
# o
# ooo
#
#
#
#
# o
#
# o
#
#
#
#
# oo
# ooo
#
#
#
#
#
#
#
#
# o
#
# o
#
# o
#
# o
# o
#
# ooo
#
#
#
#
#
# o
# oo
# oo
#
#
#
# o
#
#
# o
# o
#
# o
#
# o
#
#
#
# o
# o
#
#
#
#
# o
#
# o
#
#
# o
# o
# noo
# o
#
# oooo
# ?o
#
#
#
#
# ----- temperature: 0.5
# o
#
# no?
# mon
# o
#
# ?
# ?o
# noo??obo?ooo
#
# mo
#
#
#
# ?oo
#
#
# kk
# o
# ooo
# o??o
# k
#
#
# o?
# ?o
#
# o?o
# mo
#
# k?oooooo
# n
#
#
#
# ?o?n
# ?
#
# ?o
#
#
#
#
#
# o
#
#
# o
# ooomo
# o?oono
#
# ooo
# o?o
#
# o
# n
# o
#
# n
#
#
#
#
# o
# o?
#
# oo?o
# bo
# oo
# o??
# oo
#
#
#
# o
# ono
# oo
# om
# o
#
# nn
#
# no
# ?boo
#
# ?
#
# k?
#
#
# ooooom
#
#
# oooo
#
# o
#
# ?ookoo
#
#
# oomo?
#
#
# ?
#
# k
#
#
#
#
# on
# on
# ?m?oo
# onooo
# n
#
#
#
#
# oo
# nonkom
#
#
#
# nbn?oon
#
#
#
# bo
#
#
# n
#
# oo?o
#
# o
#
#
# mo
# mo
# omom
# ?n
# ?omnooooob
# ?bo?
#
# ?o
# n?nmom?
# oo
#
#
#
# on?o
# oo
# ??o?
# ?bon
#
#
#
#
#
# omoo
# o
#
# ----- temperature: 1.0
# ?moNnonoAobk?
# r
# ???y??n
# mn
#
# no
# ok
#
# m
#
#
# w?mo?o???boonok
# ?mo
# b
# o
#
# bN
# k
# bn
# m
#
# om
# nbboo
# ?g?mm
# onmb
# h
# ?o
# ?o
# n
# oo?m
# ?o
# o?’?rn
# b
# rb?y?p?ng
# ???omo
# n
#
#
# o??n
# o?mo?n
# n?nbo?bB
# b?o
#  bb
#
# o
# o
# hon??
# n?bo?o
# ooo?rBo??Obbk
# b
# o??ooo
# nb
# o
# bA??oob?
#
# on
# nnbmoo
#
# bnoo
# non
#
#
#
# ?obom
#
# obom
# ?oo?o??omon?
# n
#
# ?mo
#
# ooo?o?n
# n?kk?o?m
# b
# oo
#
#
#
# ooo??mbhbbrkn?noonmok
# monoo??oe
# mn?oonmo
# o?b
#
# n
#
# o?No?
# m
#
# mnkobm
#
# bbonnn
# ooooonnoonnonon
# k
#
# ----- temperature: 1.2
# bmkoo?B
# bmoook
# n’ooo
# ’
# bnbn
#
# oym
# Nk
# nk?bmoomkb?om
# aho
# bnnbmm
#  oo
# bmkromobobkbnbkm
# omommb
# o
# omm?
#
# okb
# kmwromoogh
# ’bo
#
#
#  z?m?k
# bN
# o
#
# nb
#
# bmobbnn
# o?b
#
# bnnnkhboko
# mobnkmn
# eb
# okb?
#
# kooneoJ?kbnkkmmn
# ?mk
# bmo
#
# o oo
# kOnooook?
# k
# m
# nmb
# bokoonk
# o
# b
#
# hk
# oo
# ?mb
# n
# Aokm
# o
# o?
# r
# oono
# l?
# mb
#
# n?pnnnz
# p
#
# mmo
# ob?
# ?
# okokpn?
# ?nB?o
# m
#
# ?’???ooeo?n?
# ?
# okbo??nnbknok
# om’mmomobb
# o
# o
# mmo
#
# mmbnBomono? b
# bo? n
#
# o?
# mmnJnbo
#
#
#  no
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 81s 81s/step - loss: 1.9947
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.9548
# ----- Generating text after Epoch: 16
# ----- Seed: "BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes?"
# BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes?
# ----- temperature: 0.2
#
#
#
#
#
#
#
#
#
# oo
# oo
#
# ooo
# o
# o
# o
#
# o
# o
#
#
# o
#
# o
#
#
#
#
#
#
#
#
#
# o
#
# oo
#
#
#
# o
# o
#
#
# o
#
# o
#
# o
#
# ?o
#
# oooon
# oo
# o
# o
#
#
#
#
#
#
# o
# ooo
#
# oo
#
#
#
# oooon?
#
# oo
#
#
#
# o
#
#
# oooo
# ooo
#
# ooooo
# oooo
# o
#
#
#
# o
#
#
# o
# ?
# o
#
#
#
#
#
# ?o
#
# o
# ooo
# ?
#
#
# ooo
# ooo
#
#
# oo
#
#
#
# on
#
#
#
# o
#
#
#
# ooooo
# oo
#
# oo
#
# oo
#
# o
#
#
# o
#
# o?
# o?
#
#
#
#
#
#
# o
# o
# oo
# o
#
# ooo
# o
# o
#
# o
#
# ooo
#
#
#
#
#
#
#
#
# ?
# ?oo
#
#
#
#
#
# o
# o
#
# oo
#
#
#
#
#
# o
# oooo
# ?oo
#
#
# b
#
#
# o
#
# o
#
#
# o
#
# oooooooo
#
#
# oo
# o?o
# o
#
# o
#
#
# o
# o
#
# o
#
#
#
#
#
#
# o
#
#
# ooooo
#
# o
#
# oo
#
# o?
#
# o?
# oo
#
#
#
# oo
#
# ----- temperature: 0.5
# mnooo??
#
#
# bo?mooo
#
#
# m
#
# ?o
#
#
# ok
#
#
# oon?
# ??noo
# n
# nkb
# booo?
#
# oon
# b
# ob
# ?noo
# no?obbmmbb
# ??m
# o?b
#
# o?
# o?boo
#
# ?
# oo
#
# m
# on??o
# obnn?
# om
# oo
#
# oo
# ooooon
# oo??ooo
# oooo
#
# o?
#
# ?ooonn
# mnoom
#
#
#
# o?
# om
# oo
# m
# bono
#
#
# ??oo
#
# omoo
# o
# ?kooo
#
# m
# o
#
# bo
# ooonnooonobn?o?no
#
#
#
#
#
# ?
# oo?mooo?
#
# o
#
# o
# om
# ob
# o
# ?
# bo?
# o
# ooo
#
# b??o
# oonbon
# b
#
# nnb
# ?o
# koo
# o
# ooknooo
# obo?
# nn
#
#
#
#
#
# o
# n
# o
# ??
# oo
# o
# o
# oom
#
# bboom
# ob
#
# oo
#
# n
#
# o
# oo
#
#
#
#
# nmo?n
# bo
#
# o
#
# mo?m
# mo
# ?o?m
#
# ----- temperature: 1.0
#
# onn?
# o?
# nnnmoo?z?
#
# nm
# omokno?mn
# k?oowb
#  obb?nk
# m?ob?oo
# n
#
# kmk?
# ybnb
# ?o
# eonmbo
# mmo?
# moo??m
# n
# ?onkk?bb?n
#
# kmnb?o
# ?o
#
# oo
# ??ono
# n
# m
#
# oo
# n
# mbo
# ?n?noon
# o?om
# o?b’mm
# omn??o?ko??
#
# bnb ko
# ?
#
# k
# om
#
# o
#
# kbbb
# b??o
# R
#
# m?omo
# ?
# m
# ?m?ok
# ?
#
# o
#
#
# nbmokb
#
# romobkm
# k
#
# oe b
# m
# b?
# ?o
# Bko
# nbobmAo??oooonon
#
# ?kmooo?m
# ?
# n
# ??b?
# ?okon
# b?
# oo
#
# zbpo?
# ?
# oboom?
# n?mk
#
# ob?on?o
# nm
# ob?ko
#
#
#
#
# o
# bno?okoom
# ob
#
# oooomn
# bb?ok k
#
# Rn?
# nb
# kom
# n
#
# ----- temperature: 1.2
# ombmR
# bo
#
# no
# kn
# oo
# ?bmk?on
# Nn?mbob?
# m B
# o??oono
# ?
#
# m
# go?o
# k’Nmbep
#
# mo?o?kb
#  Opo?nkn?n
# omb’O?oomn
# oo
#
# oobm?o
# ?ro
# m
# mo
#
#
#
# nnonenoonm
# ynbln
# n??nmn?
# o?oRbnbognmb
#
# A? ?
# ?obkoboy
#
# Aoo
# k?
# o
# loomo
# ?kyzmobk
# nn’
# koommoB?mmnn?
# o
# ook
# oko
# m?ok
# ?
# omoobn
# ooonoo
#
# nboo??
#
# mon??oom?nbn
#
# oh??nn
#
# Ro?
# ?mk??o?
# ?o
# oom?om okmm
# bnbok
# nR
# bkmblok
# n’nok
# lnkr
# bnomgkonmm
# ?bmm
# mo
# ?boo?oo?n?Ao?oo
# ?mmong bynJ?nmomyhobonm?nm
# obgn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 79s 79s/step - loss: 1.9548
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.9254
# ----- Generating text after Epoch: 17
# ----- Seed: "ptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? B"
# ptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? B
# ----- temperature: 0.2
# oooo
# oo
#
# oo
# o
# oo
# o
# oo
# o
#
# oo
#
# oo
# oo
# o
# oo?nmo
#
#
# onokoo
#
# o
#
#
# oo
#
# n
# ?
# b
# oo
# o
# no
#
# oo
# o
# oo
#
# ooo
#
# ooo
# o
# o
#
# o
# ooboooo
# om
# o
# o
#
# n
#
# o
#
# o
# o
#
#
# omoooo
#
#
# oooo
# oo?ooo
#
#
# oooooo
# o?oooo
#
#
#
# o
# oook
#
#
# no
#
#
#
# on
#
#
# oo
#
# ?
# o
#
#
#
#
# oomooo?o
#
#
# o
#
# bo
#
#
# n
# o
#
#
# o
#
#
#
# o
#
#
#
#
# o
#
# o
# o
# oooo
#
#
#
#
#
# o
# o
#
#
# ooonoooooo
#
#
#
#
#
# o
# o
#
#
#
#
# nm
# oononoo
#
# o?
#
# o
#
# o
# oo
#
#
# o
#
# o
#
#
# o
# o
#
#
#
#
#
#
#
# o
#
# oooo
# oooo?o
# o
# oooo
#
#
#
#
#
#
#
#
#
# oo
#
#
#
# oo
#
#
#
#
# ooo
# o
#
# ooonooo
# ooo
#
# ooono
#
#
#
# ----- temperature: 0.5
# ?
#
# oo
# oo
#
# ?
#
#
# no
# o
# ooboo
# oononb?ooo?mo
# m
# nook
# ?mo
#
#
# mm
# ommonon
# kknb?
# oo?o
#
# kom
#
# o
# monoo??obn
#
#
#
# ok
# m
# oo
# n
#
# n
# oo?oo
# bbo
# oooo
# okn?bomobooo
# ooo
# no
# moo
# ooo
# nookom
# oo
# n?ko?
# o
#
# kokoo
# mo?moom
#
# ?b
#
# m
# o
# omb?
#
# ooo
# o
# bo
# oo
# ?o
# o
# o
#
# omoo
# bnoonoko
# ?oom
# ooo
# b??omoobo
# n
# om
#
#
#
#
# m?kb?
# ?
# mo
#
# oobm
# m
#
# ?o
#
#
# ?
# koon
#
#
#
# oo
#
# momnoo
# boobo
# ??o
#
# nn
#
# boo?k
# ob
# o
# ?o
# ok?
#
# ?monobmoboo
# ob
# oo?o
#
#
# m
#
# o?no
#
# ?m
# obb
#
# onboo?
# ok
# ooomm
#
# oo
#
# ----- temperature: 1.0
#
# n
# n
# rb
# kmo?mo
#
#
# b
# oo?
#
# ?b
# n?
# ?m
#
#
#
# no?o
# o
# mnbn??b
# kom?nbmmo
# N
#
# okbob
#  ?ok
# koonoooonbn
# omnook
#
# ?on
# boboo???bN?mo
# ko’m
# m
# b?oo
# sbko
# oom?
# bn
#
# bonooo?bro
# mnm
#
# ??
# mbooboo
# k?
# b
# ?
#
# b
# n?komrmonb
#
#
# onnm??
#
#
# mmebt
# ooboo
# to?
# b?b
# o?
#
# b
# ?nk?
#
# mn
# obb?oo
# bn?bm
# n
# bomk?o’ommb?k
# okk
#
# ?
#
# b??bnoobmb
# m
# ohnb
# k
#
#
# bbo?obm
# oeooo
# k?
# ob
# nbm
# km??n
#
# nk
# k?
# k
# b?oo
# ?kb
#
#
# ??nbbm
# nomk?nbmmo??onN?bkm
# kmbkbmn?m
# no b?b
# oooonob
# o
# nbyo
#
# ----- temperature: 1.2
# tonnomookbb?’ommkb
# o?b’n?no?nn
# mnhokbooonr?om’ om
# ’oo?ok
# ??
# ?bmoobmont
# bok
# ??zmb
# o?
# ?mnobmnknbok
# mon
# nwnk?
#  o
# onbnbmoo
# ?moo?nnoky?omn?b?
# mknbono’b?b
# ’nomm
# ?nkoomkmnmmbm???nm?kb?bbb?e
#
# kozk
# ne
# nob?b
# bngnokn
# bnmn
#
# ?onk
# oo?k
# nb
# n?p
# ’nk?m
# ’?onNbor??onoA’n?b
#
#
# mbo
#
# ?o
#
#
# nbnobbok?g
# ookbomkbk
# n
#
# bbBa
# oo??mo
# ooonon?
# bnmk
# o
# on?mnoony?nonmoookrnoo?
#
# okhpkop?nnB
# l
# nn’
# m
# ?om?o?nk
#
# ?b
#
# ??
# mo
# mom?nwo moo
#
# k?eB
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 79s 79s/step - loss: 1.9254
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.9066
# ----- Generating text after Epoch: 18
# ----- Seed: "e BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem? ke"
# e BeptagzA
#
# yom’ Reser? Bonrob’
#
# lem? ke
# ----- temperature: 0.2
# moooo?
# oonboooooooo
# o
#
# obo
# b
#
# ooon
# on
# o
# ?
#
#
# on
# o
# ?
# moooob
# o
#
#
#
# o?nb
# oom
#
# o
#
# oooom
# ooo
# o
#
#
#
# m
# nooo
# oomm
#
#
# ooo
#
#
#
# oookno
# onooo
#
# oo
# o
# n
# ooom
# onoomo
# omoo
# o
# oonomob
#
#
# omo
# oom
#
# o
# nnoooo
# oooo
#
# m
# o
#
# oo
#
# bno
# o
#
# oo
#
#
#
# oo
# m
#
# o
#
# oon
# ?oonm
# oo
# m
# o
#
# oo
# ooooo
#
# ooooooo
# ooo
#
# ooo
# onoooo
# ooooo
# ooobo
# o?oom
#
#
# obooo
#
# omo
# o
#
# o
#
# oono
# oo
# oomo
#
# oo
#
#
#
# ooo
#
# ono
# ooo
#
#
# knooo
#
# ono
# oom
# o
#
# oo
#
#
#
# on
#
# o
#
# o
# o
# oom
# nooo
# k
#
#
# ?o
# oko
# oo
#
#
#
# ----- temperature: 0.5
# o
#
#
# nbomn
#
# o
# m
# n
# o
# o
#
# n
# ob?
# mo
# ??oo
#
# oooono
# oo
# ?oon
# ooom
#
# m
# om
# bo?omo
# mbb
# ko
# o?
#
# obonoo?
# n
# ononn?okn?nn
#
# oobm?b
# nbobbomko
# om
# nknn?obm?nkooonmnoonooo
# omo
#
#
# ?
# nomonmob
# koko
# mnnm?boo
# ?
# b
#
# oomoob
#
#
#
#
#
# o
# ob
#
# n
# ?
#
#
# onn
# ?nobo
# omko
#
#
#
# oooo
# ?konbomo
# mo?mn
# m
#
# km??
#
# ooon?om
# kb
# ?oo
#
# n?
#
# bonkomoo
# m
# bno
# oobo
# kooo
#
#
# obk
# oo
# k?b
# oon
#
# ookmn
# mnmboonoo
#
# bono
#
#
# ooo
#
# o
# obmmkn?bo
# kmboom
# omb
# o
# o
# knnnn?
# onmb
#
# b
#
# oooooon?o
#
# ----- temperature: 1.0
# ?nok
# Boobwb? o
#
# mRmooom
# m?omobnbnon
#
# mbom
#
# obnmmbybm?mo eoobno
# o
#
# r?o?
#
# oktb?nbb
# ?bk?omko
# bm
# R
# nbo
# nooo
# nmn??nok
#
# nkm n ??bmn
# oomn
# Nnbm
# ?m
# k
# mn
# nbm
# oo?n
# on
# nbooomno
# mk?mo?nmnmno?
# m
# b?onbn?bnmmoo
#
# ?
# boo
# nkbon
# o
# obbrbh
# b
# lm
# noklmkko?omob
# n?obbbk?b
# n
# obn Bkb
# mn
# o
#
#
# obnnoo?bkokooo?k
# obo
# No
# m?nn?bmn
# oo?ooo
# ?oboo
# mo
# ?o
# o
# o?b?oon
# b?
# m?
# mbok??n?monkmb??bbnm
# omon
# nm?
#
# boooo
# mno
# bmkmbm’mko?onnkm
# o?mr
# n?bpbn
#
# ----- temperature: 1.2
# bbmkoon
#
# r
# oo?
# mm
#
# o
# ?
# ao?
# mmmknbonm?
# nm??
# mnbmb?opoonNkbmomo
#
#
# m
# nm?B??
# k
# ?mon
#
# kkm?m??’nnnb?k
#
# n?no?ommk?
# ko
# bmbkokko
#
# onr
# o?mnbnb??nbno
# nomo?bn?ooromn
# mn
#
# bbb??
#
#
# m?nA
# m?o?bAkkmbnt
# kbmo
#
# krgmbmnb??bbbkm??mbo??
# ko
# ’b??Bmnok
# gnb?m ?
# n
# oooAknynakbob?
# nnne
# o?b
# mm
#
# ?noonnbon??oo
# ?nbk
# b?
# bnko?o
# bomn
# mogheb
# o
# ono
# mk?oo
# mb
# o
# ?bbm
# mn?m
#
# ko
# e
# ?m
# nb?b
# r
# pmmb
# ke?ooobbno
# nbm
# kmk
# mmomm
# o?
# bnbomn
# kobb’r?
# k
# kn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 79s 79s/step - loss: 1.9066
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8957
# ----- Generating text after Epoch: 19
# ----- Seed: "tagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Bo"
# tagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? Bo
# ----- temperature: 0.2
# on
# oomn
# boono
#
#
#
# ?o
# o
#
#
#
# b
#
# bm?oo
# o
#
#
# m
# n
# oo?oob
# nn
# on
# oo
#
#
#
#
#
# o
#
# o
# kooooo
#
#
# oobmoo
#
# o
# o
# ooon
# ko
# om
#
#
#
# n
# mo
#
# oon
# on
# o
# m
# ?
#
# mooo
# oo
# o
# o
# o
# nn
# m
#
# oo
# oon
#
# on
#
# oonoomob
# m
#
# o
# mo
# o
#
# om
# oboono
# o
# noo
#
#
#
#
#
# o
#
# ok
# o
# oo
#
#
# oono
# noo
# on
#
# obo
# ooo
#
#
# no
#
# on
# omoooo
# o
# oooo?
# nm
# oooobkoomoooooo
#
#
# b
#
# oo
# n
#
# nb
# omo
#
#
#
#
#
#
#
# mooommoo
# ooko?ooooooo
# o
# omooooo
#
# non
# oooo
#
# bo
# ono
#
# oo
#
#
#
# ooo
#
# mo
# m
#
# nooob
#
# oo
#
# oobo
#
#
# oo
# bom
# ono
# o
#
# mo
#
# ----- temperature: 0.5
# oonb
# ob
# bb
# b
#
# kmo
# ob?koomnmo
# oono
# o?k?
# omooo
# kno?mo
#
# mkomoobnmmm
#
#
# mn?
# nmbn
# m
#
# bm
# o
# ko
# o
# o
# oo
#
# ?o
# mobm??
# on
#
#
# ?m
# on bmn
#
#
# o
# onoko?ononoo
# nmnmk?oo
#
# ooono?nm?b
# n
# no?n?
# m?kboo
# oooo
#
# koo
# bnbbooo?boom?
# m?k
# n
#
#
# k?km?m
# ookk
# knomkbo
# k
# ob
#
# nbnom
# oomo?km?o
# n
# bonoo
#
#
#
# oonm
# bk?
#
#
# kon
#
# o
#
#
# b
# b
#
# ?m
# mo?o
# obob
# nbbboo
# m
# bk
# k?no
# o?noon
# bbmomb
#
# nooookom
# bnbk
# ?onko
#
#
# oook
# ??momn
# n
# k
#
#
# mob
# kbb
#
#
# ?
# mkoonbm?
# m
# non
#
# nboo
#
# ----- temperature: 1.0
# nmomoobb?
#
#
# oon
# n
# mbooom
# mon
#
# knmnbmm?komrb?o
# k?oob
# n
# b
# non mom
# oko
# bnbn
# kb?
# o?nne
# nln?mn
# ?
# ookokkoooAb
# omkm?omok
# obmbk?nmnk?
#
# ??
# bkbbmo
# m?bob
# on
#
# oommom
# ?moooo?nob
# mo
# ?b
# n’?nsm?m
# k
# mombbnmn
#
# bn
# m
# mmoomobbobnoobn?
# okbn?bnbom
# noobnbo?
# o
# o
# nb
# kn
# knk
# n?om’
# bolnnn
# o
# oknmn?ornbbNo?
#
# mb
# nnkmzbbok?k???o
# obonbnoobomob
#
# nob?b
# nmno
# nb
#
# ?
# onnook
# n
# omnkkno
#
# o
# g
# o
# oo
# ?oo
# kR?b
#
# o
# ooooknrnkon
# okbobnonnb
#
# obok?o
#
# ----- temperature: 1.2
#
# on
# ?
# n?
#
#
# mbob??mkomm
# k
# m?
# monbo
# k bo?nmomn?onnkbroom
# ?nnn??
# ?oonmobbrokm?mbmmm
# k
#
#
# ?
# Rnobmn
#
# kyo
# k’m
# zrbnb
# nJooo?b’oo?oboobnnmoonn
#
# bok?bm?onon
# knnnonbp?
# e?b
#
# kbob
# mbmb
#
#
#
# koo n?nkoo
# om?o?okmmbb?mmrm
# m
# n
# o?nnooo
#
# oo?Nm?kbb??okko ?bonnokonkk mbrnb?no
# mo?bbbmo?b?mmno?b
# o?
# mao?
# ?moboknnNokb
# nbk?oo??b
# gbnknnbb
# nNoonb
# oobb
# ?
# m m
# okn
# ?ook?zkmnobobn?oo
#
# kkok?onnkn?n?mkoob
# o
# ?
#
# nk?mbkmm
# kooB?mk
# ?k r?rnb
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 79s 79s/step - loss: 1.8957
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8864
# ----- Generating text after Epoch: 20
# ----- Seed: "eptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes? "
# eptagzA
#
# yom’ Reser? Bonrob’
#
# lem? kes?
# ----- temperature: 0.2
#
# oo
# noo
# moooooboono
# nnoo
#
#
# o
# o
# boooon
# oo
#
#
#
#
# ooon
#
# o
# oobk
# ooo
#
#
#
#
#
#
# o
# oo
#
#
# o
#
#
# o
# o
#
#
#
# ooooom
# ono
# oob
# on
# ?oonbo
# ono
# o
# oono
#
#
# o
#
# oooooomoo
# ooo
# oonooo
# n
# o
# ooo
# onoo
# o
#
#
# o
# n
#
#
# oooooonoooo?
#
# mn?oo
#
# oono
# kon
# o
#
# okk
#
# onb
# o
# o
# o
# o
# no
# bo
# oo
# oooo
# o
# m
#
#
#
# nooo
# ookkooo
# o
#
#
# kooo
#
# oo
#
# oo
#
# omm
#
#
# o
# o
# oomkooon
# ooook
#
# mo
# oomnooooo
# o
# o
#
#
# oo
# m
# o
# nknoooooo
#
#
# ooo
#
#
# no
# o
# moonokooomooon
#
# no
# o
# ooo
#
#
# noo
# no
#
# o
# oo
#
#
# k
# o
# onoooo
#
# ----- temperature: 0.5
# obokmmnko
#
# ?
#
#
#
# nkn
# ?monn
#
# mkbmnkn
# boo
# mm
# bokon
#
#
# nnbknmookomn
# mnmnb
# oobkbnbon
#
# ooomoonooo
# n?mo?no
# ?ooko
# kmnkmonm?mo
# n
#
# o
#
# on
#
#
#
# ko
# o
# b?ob
# n
# bbo
# ?
# ?kk
# ?
# omno
# oo
# nbm
#
# knno
# k
# oo
#
#
#
# kon
# mn
# bkokm
# n
#
# o?ob
# m
# ?m
# bmo
# mo
# oonmooo
# obbobn
# m?oob?
# o
# on
# n?o
# kn
# ok?
# omoboonkokkoomobnooon
#
# nommob
# mok
# ?
# kooo
# ?
# o
# mo
# nmkmnono
# ?o?bono
# o
# k
# b
# oon
# bbnon
#
# knmnomb
# b
#
# o
# oboooob
# o
# ?no
# no
#
#
# m
#
# b
# omooonnmookoob
# bmk?
# o
# ookko
#
# n
#
#
# ----- temperature: 1.0
# om
# noko?m
#
# bo
# m
# nkmom?no
# o
# on
# mnnmommb?znoonmmbmbooonoob
# ??okmbk?ngkokoB
# m
#
# nbnb?ngbknkooknn?kb?o
# ?Aooo?kbonb
# nbeobb?m
# bkmb
# m?b
# nk
#
# ?
# o?oobkooomnm
# nkoo?mb
# okb
# k
# b
# n?kn
# on
# non?m
# k
#
# b nbbb
# mo
#
# ?okmknook’knno
# o?on
# oo nnbno
# b
# nbb
# oobkmnk?oo
# kmm
# o
#
# bmo
# nm
# bnobbmoknb
# ?mmooooobkk
# nokmk
#
# oo
# bm
# nkp?n
# n
# mnbo
# ?
#
# nmno?mookoo
# oo?nn
#
# knnbbok
# oo
# obkbobbokkbromononn?bb
#
# bkbnmmmp
# ?bpk
# nk??mmno?nok?obk?mbbb
# bnbob
#
#
# ----- temperature: 1.2
# nn
#
# knAnnmo?oomm
# okmmnm
# mnnomnbne
#
# oobob?bnk?kmmo
# m
# ?n?m
# ?nnno?mkb
# nkoomm?bn?o’o
# kn
# o??mBo
#
#
# n
# onnnkm?mnkk
# b
# ??kokobkokn
# ko
# bnknkk
# mk
# oomk
#  on
# oonnbobm
#
# bo
# ?mokoonkmbmb?bkkmm?mkkomo?brnkbkr?obk?no
#
# b?ooon
# bkmb?obBRo
# ?r
#
# k
# oo
# npnknkm
# o
# mrbmn?
# on?
# oon?
# b??ob?obmnobb
# oomobkmononokmnko
# o
# mmbbkkoknNbonm
# mmoo
# knko
# bneomo
# mn
# nmo?oom?n
# ynkkko?m
# ?
# nmkNh
# ngnok?m
# bmm
# mobkn?nn???nnnbknk
# b?on
# aonbb?nom
# ynOJ?o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 79s 79s/step - loss: 1.8864
